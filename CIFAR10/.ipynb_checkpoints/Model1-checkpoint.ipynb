# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from datetime import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Activation
from keras.utils.np_utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from pathlib import Path
import os

Dense1_Units = 512
Dense1_Activation = "relu"

Dense2_Units = 512
Dense2_Activation = "relu"

Dense3_Units = 10
Dense3_Activation = "softmax"

LearningRate = 0.01
Decay = 0.00001
Momentum = 0.9

Epochs = 32
BatchSize = 512
ValidationSplit = 0.2

params = [f"Dense1: {Dense1_Units}, {Dense1_Activation}",
          f"Dense2: {Dense2_Units}, {Dense2_Activation}",
          f"Dense3: {Dense3_Units}, {Dense3_Activation}",
          f"Learning Rate: {LearningRate}",
          f"Decay: {Decay}",
          f"Momentum: {Momentum}",
          f"Epochs: {Epochs}",
          f"Batch Size: {BatchSize}",
          f"Validation Split: {ValidationSplit}"]

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

x_train = np.reshape(x_train,(50000,32*32*3))
x_test = np.reshape(x_test,(10000,32*32*3))

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0


model = Sequential()
model.add(InputLayer(input_shape=(32*32*3,)))
model.add(Dense(Dense1_Units, activation=Dense1_Activation))
model.add(Dense(Dense2_Units, activation=Dense2_Activation))
model.add(Dense(Dense3_Units, activation=Dense3_Activation))
mySGD = SGD(learning_rate=LearningRate, decay=Decay, momentum=Momentum)

model.compile(optimizer=mySGD, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=Epochs, batch_size=BatchSize, validation_split=ValidationSplit)

training_score = model.evaluate(x_train, y_train, verbose=0)
test_score = model.evaluate(x_test, y_test, verbose=0)

print(training_score)
print(test_score)

currentTime = datetime.now()
timeStr = currentTime.strftime("%m-%d-%Y_%H:%M:%S")

logFile = open(f"Model1_History_{timeStr}.txt", "w+")

logFile.write("Parameters:\n")
for s in params:
    logFile.write(f"{s}\n")
logFile.write("=================================================\n")

for e in range(Epochs):
    logFile.write(f"Epoch: {e+1}/{Epochs} - ")
    for key in history.history.keys():
        logFile.write(f"{key}: {round(history.history[key][e], 4)} - ")
    logFile.write("\n")
    
logFile.write("=================================================\n")
logFile.write("[Loss, Accuracy]\n")
logFile.write(f"Training Score = {training_score}\n")
logFile.write(f"Test Score = {test_score}\n")
logFile.close()
model.save(f"Model1_{timeStr}.h5")
# Out:
# Epoch 1/32
# 79/79 [==============================] - 3s 36ms/step - loss: 1.9709 - accuracy: 0.2946 - val_loss: 1.8540 - val_accuracy: 0.3275
# Epoch 2/32
# 79/79 [==============================] - 3s 34ms/step - loss: 1.7571 - accuracy: 0.3811 - val_loss: 1.7350 - val_accuracy: 0.3844
# Epoch 3/32
# 79/79 [==============================] - 3s 34ms/step - loss: 1.6762 - accuracy: 0.4092 - val_loss: 1.6640 - val_accuracy: 0.4150
# Epoch 4/32
# 79/79 [==============================] - 3s 33ms/step - loss: 1.6098 - accuracy: 0.4317 - val_loss: 1.6582 - val_accuracy: 0.4188
# Epoch 5/32
# 79/79 [==============================] - 3s 33ms/step - loss: 1.5785 - accuracy: 0.4433 - val_loss: 1.6738 - val_accuracy: 0.4031
# Epoch 6/32
# 79/79 [==============================] - 3s 33ms/step - loss: 1.5387 - accuracy: 0.4595 - val_loss: 1.5959 - val_accuracy: 0.4370
# Epoch 7/32
# 79/79 [==============================] - 3s 33ms/step - loss: 1
# 79/79 [==============================] - 5s 59ms/step - loss: 1.1132 - accuracy: 0.6091 - val_loss: 1.4203 - val_accuracy: 0.5072
# Epoch 30/32
# 79/79 [==============================] - 5s 60ms/step - loss: 1.0958 - accuracy: 0.6171 - val_loss: 1.3632 - val_accuracy: 0.5267
# Epoch 31/32
# 79/79 [==============================] - 4s 57ms/step - loss: 1.0709 - accuracy: 0.6244 - val_loss: 1.4789 - val_accuracy: 0.4901
# Epoch 32/32
# 79/79 [==============================] - 5s 58ms/step - loss: 1.0746 - accuracy: 0.6249 - val_loss: 1.3792 - val_accuracy: 0.5301
# [1.1047979593276978, 0.6160600185394287]
# [1.358339786529541, 0.5241000056266785]

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from keras.utils.np_utils import to_categorical


#Change X_Test and Y_Test for a different data set.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

y_test = to_categorical(y_test, num_classes=10)
x_test = np.reshape(x_test,(10000,32*32*3))
x_test = x_test.astype('float32') / 255.0

testModel = load_model('FINAL_MODEL1.h5')
predictions = testModel.predict(x_test)
predictionClass = []
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

for i in range(len(predictions)):
    imagePrediction = np.where(predictions[i] == predictions[i].max())
    predictionClass.append(classes[int(imagePrediction[0])])

print(predictionClass)
# Out:
# ['cat', 'ship', 'airplane', 'airplane', 'deer', 'frog', 'automobile', 'frog', 'bird', 'automobile', 'airplane', 'truck', 'dog', 'airplane', 'automobile', 'ship', 'dog', 'airplane', 'ship', 'frog', 'deer', 'airplane', 'airplane', 'truck', 'deer', 'bird', 'deer', 'airplane', 'truck', 'frog', 'frog', 'deer', 'deer', 'bird', 'truck', 'truck', 'deer', 'truck', 'automobile', 'dog', 'deer', 'frog', 'cat', 'deer', 'airplane', 'truck', 'bird', 'ship', 'deer', 'deer', 'truck', 'deer', 'frog', 'cat', 'ship', 'ship', 'horse', 'truck', 'dog', 'deer', 'horse', 'frog', 'automobile', 'automobile', 'frog', 'bird', 'automobile', 'bird', 'cat', 'truck', 'deer', 'horse', 'ship', 'ship', 'airplane', 'bird', 'truck', 'cat', 'bird', 'ship', 'airplane', 'automobile', 'automobile', 'bird', 'bird', 'horse', 'bird', 'airplane', 'ship', 'truck', 'airplane', 'deer', 'ship', 'frog', 'deer', 'dog', 'deer', 'airplane', 'airplane', 'horse', 'deer', 'deer', 'frog', 'cat', 'automobile', 'automobile', 'frog', 'frog', 'ship', 'truck', 'airplane', 'airplane', 'bird', 'deer', 'automobile', 'deer', 'airplane', 'deer', 'bird', 'dog', 'ship', 'deer', 'truck', 'bird', 'airplane', 'bird', 'ship', 'dog', 'deer', 'airplane', 'deer', 'automobile', 'automobile', 'automobile', 'automobile', 'bird', 'truck', 'horse', 'bird', 'ship', 'deer', 'dog', 'frog', 'automobile', 'truck', 'bird', 'frog', 'truck', 'horse', 'cat', 'ship', 'automobile', 'frog', 'ship', 'deer', 'dog', 'bird', 'ship', 'cat', 'deer', 'airplane', 'automobile', 'horse', 'deer', 'truck', 'deer', 'ship', 'deer', 'horse', 'airplane', 'truck', 'deer', 'automobile', 'ship', 'truck', 'truck', 'ship', 'frog', 'dog', 'truck', 'automobile', 'horse', 'frog', 'bird', 'deer', 'ship', 'frog', 'frog', 'horse', 'airplane', 'deer', 'deer', 'bird', 'automobile', 'horse', 'deer', 'ship', 'bird', 'cat', 'ship', 'horse', 'airplane', 'airplane', 'horse', 'automobile', 'frog', 'airplane', 'deer', 'horse', 'ship', 'deer', 'truck', 'cat', 'horse', 'ship', 'bird', 'ship', 'truck', 'airplane', 'horse', 'horse', 'frog', 'automobile', 'frog', 'cat', 'truck', 'deer', 'bird', 'cat', 'bird', 'dog', 'automobile', 'bird', 'airplane', 'ship', 'airplane', 'deer', 'airplane', 'frog', 'bird', 'automobile', 'truck', 'horse', 'airplane', 'airplane', 'truck', 'deer', 'airplane', 'bird', 'automobile', 'deer', 'cat', 'frog', 'truck', 'deer', 'airplane', 'frog', 'airplane', 'ship', 'automobile', 'ship', 'truck', 'frog', 'cat', 'airplane', 'ship', 'ship', 'deer', 'horse', 'airplane', 'bird', 'bird', 'frog', 'dog', 'ship', 'bird', 'airplane', 'bird', 'horse', 'dog', 'truck', 'truck', 'deer', 'automobile', 'ship', 'truck', 'automobile', 'ship', 'deer', 'truck', 'automobile', 'bird', 'deer', 'ship', 'automobile', 'deer', 'deer', 'airplane', 'airplane', 'bird', 'frog', 'bird', 'bird', 'bird', 'deer', 'airplane', 'deer', 'deer', 'automobile', 'deer', 'ship', 'frog', 'airplane', 'airplane', 'bird', 'airplane', 'bird', 'frog', 'dog', 'deer', 'bird', 'dog', 'frog', 'deer', 'frog', 'dog', 'deer', 'bird', 'truck', 'bird', 'automobile', 'truck', 'frog', 'frog', 'frog', 'truck', 'cat', 'ship', 'airplane', 'horse', 'deer', 'dog', 'airplane', 'airplane', 'ship', 'cat', 'horse', 'frog', 'ship', 'truck', 'automobile', 'automobile', 'airplane', 'bird', 'deer', 'deer', 'deer', 'horse', 'automobile', 'airplane', 'truck', 'dog', 'ship', 'airplane', 'automobile', 'deer', 'automobile', 'truck', 'airplane', 'automobile', 'deer', 'horse', 'truck', 'bird', 'bird', 'horse', 'ship', 'deer', 'ship', 'frog', 'deer', 'truck', 'airplane', 'truck', 'bird', 'airplane', 'horse', 'bird', 'bird', 'dog', 'automobile', 'airplane', 'frog', 'bird', 'bird', 'frog', 'bird', 'cat', 'airplane', 'automobile', 'truck', 'automobile', 'bird', 'airplane', 'ship', 'deer', 'airplane', 'automobile', 'ship', 'bird', 'airplane', 'airplane', 'bird', 'frog', 'truck', 'truck', 'deer', 'truck', 'horse', 'horse', 'automobile', 'deer', 'ship', 'airplane', 'bird', 'automobile', 'dog', 'deer', 'deer', 'frog', 'deer ...
